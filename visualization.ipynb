# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
query1_data = pd.read_csv("./visual1.csv")
query1_data.head()
# Out:
#                   genre  no_of_applications  max
# 0       Auto & Vehicles                  85  4.9
# 1                Sports                 331  5.0
# 2         Entertainment                 561  5.0
# 3  Simulation;Education                   3  4.5
# 4                Events                  64  5.0

# %%
plt.figure(figsize=(10,22))
plt.title("Genre specific No. of applicatios with 4+ Rating ")
sns.barplot(x=query1_data['no_of_applications'], y=query1_data['genre'])
# Out:
# <AxesSubplot: title={'center': 'Genre specific No. of applicatios with 4+ Rating '}, xlabel='no_of_applications', ylabel='genre'>

# %%
query2_data = pd.read_csv("./visual2.csv")
query2_data.head()
# Out:
#                               app_name  installs  subjectivity
# 0              Golfshot Plus: Golf GPS     50000      0.791667
# 1         21-Day Meditation Experience    100000      0.516667
# 2                  All Social Networks   1000000      0.833333
# 3  Color by Number – New Coloring Book   5000000      0.380000
# 4                               Airbnb  10000000      0.500000

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x=query2_data['installs'], y=query2_data['subjectivity'])
# Out:
# <AxesSubplot: xlabel='installs', ylabel='subjectivity'>

# %%
query3_data = pd.read_csv("./visual3.csv")
query3_data.head()
# Out:
#                    app_name   price  rating
# 0  I'm Rich - Trump Edition  400.00     3.6
# 1        I AM RICH PRO PLUS  399.99     4.0
# 2         I Am Rich Premium  399.99     4.1
# 3             I Am Rich Pro  399.99     4.4
# 4                 I am Rich  399.99     4.3
